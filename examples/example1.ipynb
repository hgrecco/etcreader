# %%
import pathlib
p = pathlib.Path("TTLG_DCMMeOH_t_555_110.etc")
import matplotlib.pyplot as plt

from etcreader.highlevel import read

bundle = read(p)

# %%
curve = bundle.data_curves[0]
print(bundle.guid)
print(curve.measurement_parameters)
print(curve.anistropy)
print(curve.first_x)
print(curve.resolution)
print(curve.curve_type)
plt.plot(curve.x, curve.y)
# Out:
# 8ee97740-fd60-42af-a487-09dced83b7cd
# ...
